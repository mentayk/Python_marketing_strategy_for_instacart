# %% [markdown]
# # Combining and Exporting Data

# %% [markdown]
# ### This script contains the following points:
#  - Merging dataframes
#  - Exporting dataframes in pkl format

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Path to the original data
path= r"/Users/mentaykoshzhanova/Desktop/Instacart Basket Analysis"
path
# Out:
# '/Users/mentaykoshzhanova/Desktop/Instacart Basket Analysis'

# %%
# Import dataframes
df_ords_prior= pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products_prior.csv'), index_col = False)
df_prods= pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
df_ords= pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col= False)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Checking column names to find a common column with orders df 
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Checking column names to find a common column with ords_prior df 
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_day_of_week  order_time  \
# 0           0   2539329        1             1                  2           8
# 1           1   2398795        1             2                  3           7
# 2           2    473747        1             3                  3          12
# 3           3   2254736        1             4                  4           7
# 4           4    431534        1             5                  4          15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Merging orders with prior orders df with flag on to see if there is a full match
df_merged=df_ords_prior.merge(df_ords, on='order_id', indicator = True)
df_merged
# Out:
#           order_id  product_id  add_to_cart_order  reordered  Unnamed: 0  \
# 0                2       33120                  1          1     3355525
# 1                2       28985                  2          1     3355525
# 2                2        9327                  3          0     3355525
# 3                2       45918                  4          1     3355525
# 4                2       30035                  5          0     3355525
# ...            ...         ...                ...        ...         ...
# 32434484   3421083       39678                  6          1      419472
# 32434485   3421083       11352                  7          0      419472
# 32434486   3421083        4600                  8          0      419472
# 32434487   3421083       24852                  9          1      419472
# 32434488   3421083        5020                 10          1      419472
#
#           user_id  order_number  order_day_of_week  order_time  \
# ...

# %%
# Exporting to pickle merged df
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
