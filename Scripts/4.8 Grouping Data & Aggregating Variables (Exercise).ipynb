# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# # This script contains the following points:
#
# Exercise:
# -
# -
# -

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Path to the original data
path= r"/Users/mentaykoshzhanova/Desktop/Instacart Basket Analysis"
path
# Out:
# '/Users/mentaykoshzhanova/Desktop/Instacart Basket Analysis'

# %%
# Import dataframe
ords_prods_merge= pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
# Subset for the 1st million entries
df = ords_prods_merge[:1000000]
df
# Out:
#         order_id  product_id  add_to_cart_order  reordered  Unnamed: 0_x  \
# 0              2       33120                  1          1       3355525
# 1             26       33120                  5          0       2549350
# 2            120       33120                 13          0        395303
# 3            327       33120                  5          1        976751
# 4            390       33120                 28          1       2764474
# ...          ...         ...                ...        ...           ...
# 999995   3291169       13176                  8          1        442189
# 999996   3291170       13176                  1          1       2641101
# 999997   3291174       13176                  4          1       1776134
# 999998   3291195       13176                  3          1        952663
# 999999   3291204       13176                  7          1       2429000
#
#         user_id  order_number  order_day_of_week  order_time  \
# 0        202279             3                  5           9
# 1        153404             2                  0          16
# 2         23750            11                  6           8
# 3         58707            21                  6           9
# 4        166654            48                  0          12
# ...         ...           ...                ...         ...
# 999995    26607            29                  1           8
# 999996   158997             6                  0          20
# 999997   106645            13                  1          14
# 999998    57149            14                  3          15
# 999999   146147            88                  6          20
#
#         days_since_prior_order  ...            product_name  aisle_id  \
# 0                          8.0  ...      Organic Egg Whites        86
# 1                          7.0  ...      Organic Egg Whites        86
# 2                         10.0  ...      Organic Egg Whites        86
# 3                          8.0  ...      Organic Egg Whites        86
# 4                          9.0  ...      Organic Egg Whites        86
# ...                        ...  ...                     ...       ...
# 999995                     6.0  ...  Bag of Organic Bananas        24
# 999996                     7.0  ...  Bag of Organic Bananas        24
# 999997                    11.0  ...  Bag of Organic Bananas        24
# 999998                    30.0  ...  Bag of Organic Bananas        24
# 999999                     2.0  ...  Bag of Organic Bananas        24
#
#        department_id  prices  exists    price_range_loc price_ranged_loc  \
# 0                 16    11.3    both  Mid-range product              NaN
# 1                 16    11.3    both  Mid-range product              NaN
# 2                 16    11.3    both  Mid-range product              NaN
# 3                 16    11.3    both  Mid-range product              NaN
# 4                 16    11.3    both  Mid-range product              NaN
# ...              ...     ...     ...                ...              ...
# 999995             4    10.3    both  Mid-range product              NaN
# 999996             4    10.3    both  Mid-range product              NaN
# 999997             4    10.3    both  Mid-range product              NaN
# 999998             4    10.3    both  Mid-range product              NaN
# 999999             4    10.3    both  Mid-range product              NaN
#
#           Busiest days Busiest_period_of_day     Busiest day
# 0       Regularly busy           Most orders  Regularly busy
# 1         Busiest days           Most orders    Busiest days
# 2       Regularly busy        Average orders  Regularly busy
# 3       Regularly busy           Most orders  Regularly busy
# 4         Busiest days           Most orders    Busiest days
# ...                ...                   ...             ...
# 999995    Busiest days        Average orders  Regularly busy
# 999996    Busiest days        Average orders    Busiest days
# 999997    Busiest days           Most orders  Regularly busy
# 999998    Slowest days           Most orders    Slowest days
# 999999  Regularly busy        Average orders  Regularly busy
#
# [1000000 rows x 22 columns]

# %%
df.shape
# Out:
# (1000000, 22)

# %%
df.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered  Unnamed: 0_x  user_id  \
# 0         2       33120                  1          1       3355525   202279
# 1        26       33120                  5          0       2549350   153404
# 2       120       33120                 13          0        395303    23750
# 3       327       33120                  5          1        976751    58707
# 4       390       33120                 28          1       2764474   166654
# 5       537       33120                  2          1       2985383   180135
# 6       582       33120                  7          1       3204665   193223
# 7       608       33120                  5          1       1514503    91030
# 8       623       33120                  1          1        627389    37804
# 9       689       33120                  4          1       1813801   108932
#
#    order_number  order_day_of_week  order_time  days_since_prior_order  ...  \
# 0             3                  5           9                     8.0  ...
# 1             2                  0          16                     7.0  ...
# 2            11                  6           8                    10.0  ...
# 3            21                  6           9                     8.0  ...
# 4            48                  0          12                     9.0  ...
# 5            15                  2           8                     3.0  ...
# 6             6                  2          19                    10.0  ...
# 7            11                  3          21                    12.0  ...
# 8            63                  3          12                     3.0  ...
# 9            16                  1          13                     3.0  ...
#
#          product_name  aisle_id department_id  prices  exists  \
# 0  Organic Egg Whites        86            16    11.3    both
# 1  Organic Egg Whites        86            16    11.3    both
# 2  Organic Egg Whites        86            16    11.3    both
# 3  Organic Egg Whites        86            16    11.3    both
# 4  Organic Egg Whites        86            16    11.3    both
# 5  Organic Egg Whites        86            16    11.3    both
# 6  Organic Egg Whites        86            16    11.3    both
# 7  Organic Egg Whites        86            16    11.3    both
# 8  Organic Egg Whites        86            16    11.3    both
# 9  Organic Egg Whites        86            16    11.3    both
#
#      price_range_loc price_ranged_loc    Busiest days Busiest_period_of_day  \
# 0  Mid-range product              NaN  Regularly busy           Most orders
# 1  Mid-range product              NaN    Busiest days           Most orders
# 2  Mid-range product              NaN  Regularly busy        Average orders
# 3  Mid-range product              NaN  Regularly busy           Most orders
# 4  Mid-range product              NaN    Busiest days           Most orders
# 5  Mid-range product              NaN  Regularly busy        Average orders
# 6  Mid-range product              NaN  Regularly busy        Average orders
# 7  Mid-range product              NaN    Slowest days        Average orders
# 8  Mid-range product              NaN    Slowest days           Most orders
# 9  Mid-range product              NaN    Busiest days           Most orders
#
#       Busiest day
# 0  Regularly busy
# 1    Busiest days
# 2  Regularly busy
# 3  Regularly busy
# 4    Busiest days
# 5  Regularly busy
# 6  Regularly busy
# 7    Slowest days
# 8    Slowest days
# 9  Regularly busy
#
# [10 rows x 22 columns]

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 3                14.898875
# 4                18.847057
# 7                16.462291
# 11               17.419048
# 12               19.215747
# 13               16.473586
# 14               13.120454
# 16               18.867191
# 19               14.369608

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 3                14.898875   1  99
# 4                18.847057   1  99
# 7                16.462291   1  99
# 11               17.419048   1  71
# 12               19.215747   1  99
# 13               16.473586   1  99
# 14               13.120454   1  99
# 16               18.867191   1  99
# 19               14.369608   1  99

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
ords_prods_merge.head(15)
# Out:
#     order_id  product_id  add_to_cart_order  reordered  Unnamed: 0_x  user_id  \
# 0          2       33120                  1          1       3355525   202279
# 1         26       33120                  5          0       2549350   153404
# 2        120       33120                 13          0        395303    23750
# 3        327       33120                  5          1        976751    58707
# 4        390       33120                 28          1       2764474   166654
# 5        537       33120                  2          1       2985383   180135
# 6        582       33120                  7          1       3204665   193223
# 7        608       33120                  5          1       1514503    91030
# 8        623       33120                  1          1        627389    37804
# 9        689       33120                  4          1       1813801   108932
# 10       726       33120                  3          1        956084    57362
# 11       771       33120                 29          1       1230777    73968
# 12       800       33120                  3          1       2205942   132856
# 13       901       33120                  3          1       2669006   160657
# 14      1005       33120                  5          1       1811669   108796
#
#     order_number  order_day_of_week  order_time  days_since_prior_order  ...  \
# 0              3                  5           9                     8.0  ...
# 1              2                  0          16                     7.0  ...
# 2             11                  6           8                    10.0  ...
# 3             21                  6           9                     8.0  ...
# 4             48                  0          12                     9.0  ...
# 5             15                  2           8                     3.0  ...
# 6              6                  2          19                    10.0  ...
# 7             11                  3          21                    12.0  ...
# 8             63                  3          12                     3.0  ...
# 9             16                  1          13                     3.0  ...
# 10            25                  2          17                     7.0  ...
# 11            16                  0          17                     7.0  ...
# 12             3                  5           7                     3.0  ...
# 13            31                  1          23                     8.0  ...
# 14            11                  2          14                     6.0  ...
#
#    aisle_id  department_id prices  exists    price_range_loc  \
# 0        86             16   11.3    both  Mid-range product
# 1        86             16   11.3    both  Mid-range product
# 2        86             16   11.3    both  Mid-range product
# 3        86             16   11.3    both  Mid-range product
# 4        86             16   11.3    both  Mid-range product
# 5        86             16   11.3    both  Mid-range product
# 6        86             16   11.3    both  Mid-range product
# 7        86             16   11.3    both  Mid-range product
# 8        86             16   11.3    both  Mid-range product
# 9        86             16   11.3    both  Mid-range product
# 10       86             16   11.3    both  Mid-range product
# 11       86             16   11.3    both  Mid-range product
# 12       86             16   11.3    both  Mid-range product
# 13       86             16   11.3    both  Mid-range product
# 14       86             16   11.3    both  Mid-range product
#
#     price_ranged_loc    Busiest days Busiest_period_of_day     Busiest day  \
# 0                NaN  Regularly busy           Most orders  Regularly busy
# 1                NaN    Busiest days           Most orders    Busiest days
# 2                NaN  Regularly busy        Average orders  Regularly busy
# 3                NaN  Regularly busy           Most orders  Regularly busy
# 4                NaN    Busiest days           Most orders    Busiest days
# 5                NaN  Regularly busy        Average orders  Regularly busy
# 6                NaN  Regularly busy        Average orders  Regularly busy
# 7                NaN    Slowest days        Average orders    Slowest days
# 8                NaN    Slowest days           Most orders    Slowest days
# 9                NaN    Busiest days           Most orders  Regularly busy
# 10               NaN  Regularly busy        Average orders  Regularly busy
# 11               NaN    Busiest days        Average orders    Busiest days
# 12               NaN  Regularly busy        Average orders  Regularly busy
# 13               NaN    Busiest days         Fewest orders  Regularly busy
# 14               NaN  Regularly busy           Most orders  Regularly busy
#
#    max_order
# 0          8
# 1         32
# 2         13
# 3         30
# 4         62
# 5         99
# 6         40
# 7         38
# 8         63
# 9         24
# 10        56
# 11        36
# 12        26
# 13        36
# 14        15
#
# [15 rows x 23 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0    202279      New customer             3
# 1    153404  Regular customer             2
# 2     23750  Regular customer            11
# 3     58707  Regular customer            21
# 4    166654    Loyal customer            48
# 5    180135    Loyal customer            15
# 6    193223  Regular customer             6
# 7     91030  Regular customer            11
# 8     37804    Loyal customer            63
# 9    108932  Regular customer            16
# 10    57362    Loyal customer            25
# 11    73968  Regular customer            16
# 12   132856  Regular customer             3
# 13   160657  Regular customer            31
# 14   108796  Regular customer            11
# 15    30502  Regular customer             5
# 16   113928  Regular customer            12
# 17    29456      New customer             6
# 18    25085    Loyal customer            78
# 19   108338  Regular customer             3
# 20    67308  Regular customer            11
# 21    20944    Loyal customer            54
# 22    37557  Regular customer            15
# 23   168005    Loyal customer            31
# 24   173056      New customer             4
# 25     2555    Loyal customer            21
# 26   116952  Regular customer            13
# 27    42591  Regular customer             4
# 28    66340  Regular customer            13
# 29   112555  Regular customer            18
# 30   170703  Regular customer            20
# 31    66781  Regular customer             9
# 32   126715    Loyal customer            17
# 33    25781      New customer             6
# 34   129196  Regular customer            14
# 35   140576  Regular customer             7
# 36    88415      New customer             5
# 37   162759  Regular customer            23
# 38      155  Regular customer            15
# 39    92179      New customer             1
# 40    78567  Regular customer             2
# 41    56509      New customer             4
# 42   155845  Regular customer            11
# 43   147684    Loyal customer            14
# 44   100101  Regular customer             6
# 45   188156  Regular customer            19
# 46    40092      New customer             8
# 47    84096      New customer             2
# 48   113565  Regular customer             6
# 49    74197    Loyal customer             9
# 50    31900  Regular customer             8
# 51    97593  Regular customer            15
# 52   114300    Loyal customer            22
# 53    68183  Regular customer             1
# 54    79460  Regular customer            24
# 55   142813  Regular customer             7
# 56   124123      New customer             1
# 57   204271    Loyal customer            38
# 58   107179  Regular customer            28
# 59   190854  Regular customer             3
